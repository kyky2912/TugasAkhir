# %% [markdown]
# # Melakukan Prediksi dengan menggunakan model LSTM

# %% [markdown]
# Model LSTM (Long Short Term Memory) merupakan Deep Neural Network yang mampu melakukan prediksi pergerakan saham ataupun jenis prediksi lainnya. Untuk menggunakan model ini, ada beberapa hal yang harus diperlukan, yaitu :
#
# Membuat data generator
# Sebelum membuat data generator, data harus dibersihkan dan dilakukan Pre-processing
# Menentukan hyperparameter yang tepat untuk meminimalisir nilai Error
# Untuk menentukan nilai hyperparameter yang tepat, dapat dilihat
# Melakukan visualisasi dan evaluasi
# Menganalisa secara teknikal yang bisa dilihat

# %% [markdown]
# # Membersihkan Data dan melakukan Pre-Processing

# %% [markdown]
# ## Library yang digunakan

# %% [markdown]
# Tahap awal adalah menentukan dan mendownload library yang akan digunakan. Di bawah ini adalah library - library yang akan digunakan dalam penelitian ini

# %%
# Numpy untuk formatting number atau array
import numpy as np

# Pandas untuk membuat DataFrame dan membaca dokumen csv
import pandas as pd 

# Tensorflow dan Keras sebagai Framework dan Backend
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback
from tensorflow.keras import optimizers

# Sklearn sebagai komponen machine learning, untuk normalisasi, membagi dataset dan menghitung nilai error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Logging untuk mencatat tiap aktivitas yang dilakukan sistem
import logging

# Pickle untuk mengambil model jika sudah dibuat sebelumnya
import pickle

# OS untuk operation system, sys untuk system, time untuk waktu, tqdm notebook untuk notebook jika dibuat selain google colab
import os
import sys
import time
from tqdm.notebook import tqdm_notebook
# Out:
# Using TensorFlow backend.

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
logging.getLogger("tensorflow").setLevel(logging.ERROR)
os.environ['TZ'] = 'Asia/Jakarta'  # to set timezone; needed when running on cloud
time.localtime()
# Out:
# time.struct_time(tm_year=2022, tm_mon=4, tm_mday=11, tm_hour=13, tm_min=7, tm_sec=4, tm_wday=0, tm_yday=101, tm_isdst=0)

# %% [markdown]
# Dataset yang digunakan berupa Historical Data Price PT BMRI Tbk sejak 2011 sampai 2021

# %%
# Reading The Data
data = pd.read_csv('inputs/BMRI.JK.csv', index_col='Date', parse_dates = True)

# %%
params = {
    "batch_size": 64, 
    "epochs": 200,
    "lr": 0.0001,
    "time_steps": 60
}
iter_changes = "dropout_layers_0.4_0.4"

# %%
INPUT_PATH = "C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI"+"/inputs"
OUTPUT_PATH = "C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstm"+"iter_changes"
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]
stime = time.time()

# %%
if not os.path.exists(OUTPUT_PATH):
  os.makedirs(OUTPUT_PATH)
  print("Direktori output dibuat di ", OUTPUT_PATH)
else:
  print("Direktori sudah dibuat sebelumnya")
# Out:
# Direktori sudah dibuat sebelumnya

# %%
stime = time.time()
print(os.listdir(INPUT_PATH))

# Membaca Dataset
df = pd.read_csv(os.path.join(INPUT_PATH, "BMRI.JK.csv"), engine='python')
df = df.dropna()
df = df.reset_index(drop=True)
print(df.shape)
print(df.columns)
display(df.head(5))

# Menampilkan Feature dan Tipe Data yang digunakan
print("\n Tipe data pada Fitur yang digunakan :")
print(df.dtypes)

# Mendefinisikan variable baru untuk menampung Feature
train_cols = ["Open","High","Low","Close","Volume"]

# Membagi dataset menjadi 80% untuk Data Latih dan 20% untuk Data Uji
df_train, df_test = train_test_split(df, train_size=0.8, test_size=0.2, shuffle=False)
print("\nBanyaknya Data Latih : ", len(df_train))
print("Banyaknya Data Uji : ", len(df_test))
# Out:
# ['BMRI.JK.csv']
# (1507, 7)
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
#          Date    Open    High     Low   Close    Adj Close      Volume
# 0  2016-01-04  4600.0  4675.0  4537.5  4625.0  3562.348633  30333800.0
# 1  2016-01-05  4625.0  4775.0  4625.0  4687.5  3610.488525  53076200.0
# 2  2016-01-06  4725.0  4762.5  4675.0  4675.0  3600.860840  53073800.0
# 3  2016-01-07  4575.0  4625.0  4550.0  4550.0  3504.581055  46098200.0
# 4  2016-01-08  4550.0  4637.5  4550.0  4637.5  3571.976563  48554600.0
#  Tipe data pada Fitur yang digunakan :
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#
# Banyaknya Data Latih :  1205
# Banyaknya Data Uji :  302

# %%
# Split skip 2 hari untuk prediksi tanggal 4, dimulai dari tanggal 2 januari, 27 desember dll
df2 = df.iloc[::2]
df2_train, df2_test = train_test_split(df2, train_size=0.8, test_size=0.2, shuffle=False)
print("\nBanyaknya Data Latih : ", len(df2_train))
print("Banyaknya Data Uji : ", len(df2_test))
df2.tail()
# Out:
# Banyaknya Data Latih :  603
# Banyaknya Data Uji :  151
#             Date    Open    High     Low   Close    Adj Close      Volume
# 1498  2021-12-20  7100.0  7150.0  7075.0  7075.0  6753.044434  28966300.0
# 1500  2021-12-22  7175.0  7200.0  7050.0  7050.0  6729.182129  17407200.0
# 1502  2021-12-24  7100.0  7150.0  6950.0  7050.0  6729.182129  27451100.0
# 1504  2021-12-28  7050.0  7050.0  6975.0  7050.0  6729.182129  19917700.0
# 1506  2021-12-30  7100.0  7125.0  7025.0  7025.0  6705.319824  17475800.0

# %%
# Split skip 2 hari untuk prediksi tanggal 5, dimulai dari tanggal 3 januari, 30 desember dll
df3 = df.iloc[1::2]
df3_train, df3_test = train_test_split(df3, train_size=0.8, test_size=0.2, shuffle=False)
print("\nBanyaknya Data Latih : ", len(df3_train))
print("Banyaknya Data Uji : ", len(df3_test))
df3.tail()
# Out:
# Banyaknya Data Latih :  602
# Banyaknya Data Uji :  151
#             Date    Open    High     Low   Close    Adj Close      Volume
# 1497  2021-12-17  7225.0  7225.0  7075.0  7150.0  6824.631836  41972600.0
# 1499  2021-12-21  7150.0  7250.0  7100.0  7150.0  6824.631836  24929800.0
# 1501  2021-12-23  7050.0  7150.0  7050.0  7075.0  6753.044434  22282500.0
# 1503  2021-12-27  7050.0  7100.0  6975.0  7000.0  6681.457520  17048200.0
# 1505  2021-12-29  7075.0  7125.0  7000.0  7100.0  6776.906738  10430100.0

# %% [markdown]
# ##  Visualisasi terhadap dataset

# %% [markdown]
# Visualisasi ini bertujuan untuk mengetahui OHLC (Open, High, Low, Close) dengan menampilkan nya berbentuk grafik candle stick

# %%
import plotly.graph_objects as go
import pandas as pd
from datetime import datetime

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.show()
# Out:
# <div>                            <div id="28ab0bff-209e-4e25-ac05-d0eafd817d50" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28ab0bff-209e-4e25-ac05-d0eafd817d50")) {                    Plotly.newPlot(                        "28ab0bff-209e-4e25-ac05-d0eafd817d50",                        [{"close":[4625.0,4687.5,4675.0,4550.0,4637.5,4550.0,4600.0,4675.0,4675.0,4637.5,4637.5,4687.5,4662.5,4650.0,4687.5,4762.5,4762.5,4775.0,4750.0,4800.0,4812.5,4750.0,4687.5,4800.0,5175.0,5025.0,4912.5,5000.0,4862.5,4900.0,4875.0,4850.0,4862.5,4650.0,4700.0,4625.0,4700.0,4662.5,4737.5,4775.0,4725.0,4812.5,4850.0,4887.5,4987.5,5000.0,5050.0,5050.0,5050.0,5087.5,5087.5,5050.0,5050.0,5075.0,5150.0,5125.0,5112.5,5037.5,5100.0,5175.0,5150.0,5050.0,5087.5,5187.5,5187.5,5150.0,4925.0,4925.0,4775.0,4775.0,4775.0,4775.0,4775.0,4775.0,4875.0,4937.5,4987.5,4837.5,4750.0,4812.5,4912.5,4825.0,4775.0,4925.0,4850.0,4650.0,4725.0,4812.5,4750.0,4650.0,4512.5,4375.0,4400.0,4475.0,4350.0,4425.0,4425.0,4537.5,4500.0,4525.0,4637.5,4512.5,4600.0,4612.5,4562.5,4637.5,4737.5,4750.0,4637.5,4637.5,4525.0,4487.5,4500.0,4475.0,4475.0,4537.5,4500.0,4500.0,4537.5,4525.0,4500.0,4725.0,4800.0,4762.5,4700.0,4850.0,5087.5,4950.0,4800.0,4837.5,4837.5,5050.0,5212.5,5062.5,4962.5,4962.5,4925.0,5050.0,5050.0,5050.0,5275.0,5325.0,5212.5,5275.0,5700.0,5825.0,5900.0,5775.0,5587.5,5537.5,5587.5,5662.5,5712.5,5725.0,5700.0,5650.0,5675.0,5700.0,5700.0,5587.5,5637.5,5612.5,5537.5,5587.5,5587.5,5587.5,5637.5,5600.0,5425.0,5337.5,5300.0,5487.5,5537.5,5612.5,5700.0,5687.5,5825.0,5750.0,5825.0,5875.0,5650.0,5712.5,5600.0,5637.5,5600.0,5500.0,5475.0,5450.0,5450.0,5425.0,5500.0,5525.0,5675.0,5687.5,5700.0,5687.5,5650.0,5612.5,5600.0,5587.5,5537.5,5662.5,5687.5,5737.5,5712.5,5750.0,5575.0,5550.0,5687.5,5787.5,5675.0,5712.5,5425.0,5162.5,5275.0,5412.5,5450.0,5462.5,5350.0,5462.5,5450.0,5050.0,5075.0,5075.0,5162.5,5250.0,5250.0,5350.0,5325.0,5325.0,5350.0,5475.0,5487.5,5412.5,5437.5,5400.0,5375.0,5412.5,5400.0,5375.0,5375.0,5387.5,5400.0,5575.0,5787.5,5787.5,5787.5,5650.0,5675.0,5625.0,5687.5,5637.5,5700.0,5687.5,5650.0,5550.0,5462.5,5462.5,5525.0,5525.0,5500.0,5487.5,5500.0,5500.0,5450.0,5487.5,5512.5,5450.0,5487.5,5500.0,5537.5,5687.5,5700.0,5612.5,5737.5,5700.0,5725.0,5712.5,5712.5,5600.0,5537.5,5637.5,5575.0,5650.0,5575.0,5550.0,5587.5,5650.0,5675.0,5662.5,5675.0,5650.0,5662.5,5662.5,5687.5,5700.0,5700.0,5712.5,5725.0,5787.5,5812.5,5887.5,5900.0,5887.5,5950.0,5950.0,5850.0,5887.5,5887.5,5850.0,5875.0,5875.0,5875.0,6212.5,6100.0,6025.0,5875.0,5850.0,5825.0,5812.5,5875.0,5875.0,5762.5,5700.0,5775.0,5912.5,5862.5,5850.0,5837.5,5787.5,5850.0,5987.5,6025.0,6000.0,6012.5,6000.0,6062.5,5987.5,6000.0,6075.0,6450.0,6262.5,6125.0,6200.0,6075.0,6175.0,6212.5,6300.0,6300.0,6300.0,6337.5,6250.0,6200.0,6162.5,6112.5,6112.5,6125.0,6250.0,6250.0,6237.5,6237.5,6262.5,6350.0,6375.0,6375.0,6375.0,6375.0,6375.0,6375.0,6375.0,6750.0,6750.0,6662.5,6662.5,6625.0,6550.0,6487.5,6612.5,6700.0,6775.0,6787.5,6762.5,6662.5,6750.0,6525.0,6637.5,6675.0,6675.0,6687.5,6687.5,6825.0,6700.0,6637.5,6562.5,6537.5,6587.5,6712.5,6700.0,6662.5,6600.0,6625.0,6650.0,6662.5,6662.5,6550.0,6600.0,6625.0,6637.5,6600.0,6587.5,6612.5,6550.0,6550.0,6550.0,6550.0,6525.0,6537.5,6475.0,6512.5,6637.5,6600.0,6600.0,6575.0,6550.0,6625.0,6575.0,6600.0,6600.0,6600.0,6600.0,6575.0,6550.0,6600.0,6575.0,6725.0,6700.0,6700.0,6650.0,6600.0,6600.0,6600.0,6700.0,6725.0,6825.0,6775.0,6925.0,7025.0,7075.0,6975.0,7100.0,6950.0,6825.0,7000.0,7025.0,6950.0,7075.0,7050.0,7100.0,7275.0,7250.0,7225.0,7125.0,7175.0,7075.0,7050.0,7050.0,6950.0,6975.0,7100.0,7325.0,7425.0,7400.0,7375.0,7450.0,7450.0,7425.0,7425.0,7400.0,7400.0,7400.0,7450.0,7475.0,7475.0,7350.0,7475.0,7475.0,7450.0,7475.0,7475.0,7425.0,7500.0,7475.0,7450.0,7625.0,7 ...

# %% [markdown]
# # Melakukan Normalisasi data

# %% [markdown]
# Normalisasi data dilakukan untuk memudahkan melakukan prediksi. Normalisasi yang digunakan berupa MinMaxScaller.

# %%
# Melakukan Normalisasi untuk Data Latih dan Data Uji
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])

# %%
# Melakukan Normalisasi untuk Data Latih dan Data Uji
x2 = df2_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x2_train = min_max_scaler.fit_transform(x2)
x2_test = min_max_scaler.transform(df2_test.loc[:,train_cols])

# %%
# Melakukan Normalisasi untuk Data Latih dan Data Uji
x3 = df3_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
x3_train = min_max_scaler.fit_transform(x3)
x3_test = min_max_scaler.transform(df3_test.loc[:,train_cols])

# %% [markdown]
# # Menghapus data yang tidak diperlukan

# %%
print("Menghapus dataframe yang tidak terpakai . . .")
apus  = (sys.getsizeof(df)+sys.getsizeof(df_train)+sys.getsizeof(df_test))//1024
print ("Dataframe terhapus sebesar ", apus ," KB")
del df_test
del df_train
del x
print ("Proses penghapusan selesai")
# Out:
# Menghapus dataframe yang tidak terpakai . . .
# Dataframe terhapus sebesar  350  KB
# Proses penghapusan selesai

# %%
print("Menghapus dataframe yang tidak terpakai . . .")
apus  = (sys.getsizeof(df2)+sys.getsizeof(df2_train)+sys.getsizeof(df2_test))//1024
print ("Dataframe terhapus sebesar ", apus ," KB")
del df2_test
del df2_train
del x2
print ("Proses penghapusan selesai")
# Out:
# Menghapus dataframe yang tidak terpakai . . .
# Dataframe terhapus sebesar  175  KB
# Proses penghapusan selesai

# %%
print("Menghapus dataframe yang tidak terpakai . . .")
apus  = (sys.getsizeof(df3)+sys.getsizeof(df3_train)+sys.getsizeof(df3_test))//1024
print ("Dataframe terhapus sebesar ", apus ," KB")
del df3_test
del df3_train
del x3
print ("Proses penghapusan selesai")
# Out:
# Menghapus dataframe yang tidak terpakai . . .
# Dataframe terhapus sebesar  175  KB
# Proses penghapusan selesai

# %% [markdown]
# # Proses Data Generator untuk Model LSTM

# %% [markdown]
# Proses ini terdiri dari beberapa step, yaitu :
#
# Memangkas dataset
# Membuat time series

# %% [markdown]
# ## Memangkas Dataset

# %% [markdown]
# Pemangkasan ini bertujuan untuk membuang data yang tidak diperlukan

# %%
def print_time(text, stime):
    seconds = (time.time()-stime)
    print(text, seconds//60,"menit : ",np.round(seconds%60),"detik")

# %%
def trim_dataset(mat,batch_size):
    no_of_rows_drop = mat.shape[0]%batch_size
    if no_of_rows_drop > 0:
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %% [markdown]
# ## Membuat Time Series

# %% [markdown]
# Hal ini dilakukan untuk mengubah dimensi dari dataset, yang semula 2 dimensi, menjadi 3 dimensi. Dimensi tersebut adalah input data, jumlah data yang akan dijadikan ukuran untuk back-forward dan feature yang digunakan

# %%
def build_timeseries(mat, y_col_index):
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))
    print("dim_0",dim_0)
    for i in tqdm_notebook(range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    print("Ukuran time-series untuk Input dan Output : ",x.shape,y.shape)
    return x, y

# %%
# Pengecekan data yang masih null
print("Apa masih ada data yang berisikan null?",np.isnan(x_train).any(), np.isnan(x_train).any())
x_t, y_t = build_timeseries(x_train, 3)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
print("Data yang sudah dipangkas menjadi : ",x_t.shape, y_t.shape)
# Out:
# Apa masih ada data yang berisikan null? False False
# dim_0 1145
#   0%|          | 0/1145 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (1145, 60, 5) (1145,)
# Data yang sudah dipangkas menjadi :  (1088, 60, 5) (1088,)

# %%
# Pengecekan data yang masih null
print("Apa masih ada data yang berisikan null?",np.isnan(x2_train).any(), np.isnan(x2_train).any())
x2_t, y2_t = build_timeseries(x2_train, 3)
x2_t = trim_dataset(x2_t, BATCH_SIZE)
y2_t = trim_dataset(y2_t, BATCH_SIZE)
print("Data yang sudah dipangkas menjadi : ",x2_t.shape, y2_t.shape)
# Out:
# Apa masih ada data yang berisikan null? False False
# dim_0 543
#   0%|          | 0/543 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (543, 60, 5) (543,)
# Data yang sudah dipangkas menjadi :  (512, 60, 5) (512,)

# %%
# Pengecekan data yang masih null
print("Apa masih ada data yang berisikan null?",np.isnan(x3_train).any(), np.isnan(x3_train).any())
x3_t, y3_t = build_timeseries(x3_train, 3)
x3_t = trim_dataset(x3_t, BATCH_SIZE)
y3_t = trim_dataset(y3_t, BATCH_SIZE)
print("Data yang sudah dipangkas menjadi : ",x3_t.shape, y3_t.shape)
# Out:
# Apa masih ada data yang berisikan null? False False
# dim_0 542
#   0%|          | 0/542 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (542, 60, 5) (542,)
# Data yang sudah dipangkas menjadi :  (512, 60, 5) (512,)

# %%
# Membuat Time-Series dari data uji
x_temp, y_temp = build_timeseries(x_test, 3)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)
# Out:
# dim_0 242
#   0%|          | 0/242 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (242, 60, 5) (242,)

# %%
# Membuat Time-Series dari data uji
x2_temp, y2_temp = build_timeseries(x2_test, 3)
x2_val, x2_test_t = np.split(trim_dataset(x2_temp, BATCH_SIZE),2)
y2_val, y2_test_t = np.split(trim_dataset(y2_temp, BATCH_SIZE),2)
# Out:
# dim_0 91
#   0%|          | 0/91 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (91, 60, 5) (91,)

# %%
# Membuat Time-Series dari data uji
x3_temp, y3_temp = build_timeseries(x3_test, 3)
x3_val, x3_test_t = np.split(trim_dataset(x3_temp, BATCH_SIZE),2)
y3_val, y3_test_t = np.split(trim_dataset(y3_temp, BATCH_SIZE),2)
# Out:
# dim_0 91
#   0%|          | 0/91 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (91, 60, 5) (91,)

# %%
print("Banyaknya ukuran data validasi :", x_val.shape, y_val.shape)
# Out:
# Banyaknya ukuran data validasi : (96, 60, 5) (96,)

# %%
print("Banyaknya ukuran data validasi :", x2_val.shape, y2_val.shape)
# Out:
# Banyaknya ukuran data validasi : (32, 60, 5) (32,)

# %%
print("Banyaknya ukuran data validasi :", x3_val.shape, y3_val.shape)
# Out:
# Banyaknya ukuran data validasi : (32, 60, 5) (32,)

# %% [markdown]
# # Membuat model LSTM

# %% [markdown]
# Pembuatan model ini tidak terlepas dari hyperparameter yang digunakan, banyanya sel LSTM yang dibuat dan banyaknya hidden layer yang dibuat

# %%
def create_model():
    lstm_model = Sequential()
    # (batch_size, timesteps, data_dim)
    lstm_model.add(LSTM(256, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
                        dropout=0.0, recurrent_dropout=0.0, stateful=True, return_sequences=True,
                        kernel_initializer='random_uniform'))
    lstm_model.add(Dropout(0.2))
    lstm_model.add(LSTM(256, dropout=0.2))
    lstm_model.add(Dropout(0.2))
    lstm_model.add(Dense(128,activation='tanh'))
    lstm_model.add(Dense(1,activation='sigmoid'))
    #optimizer = optimizers.RMSprop(lr=params["lr"])
    optimizer = tf.keras.optimizers.Adam() # ini yg paling optimal
    # optimizer = optimizers.SGD(lr=0.000001, decay=1e-6, momentum=0.9, nesterov=True)
    lstm_model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return lstm_model

# %%
model = None
try:
    model = pickle.load(open("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5", 'rb'))
    print("Model ditemukan. Menggunakan model yang sudah ada . . .")
except FileNotFoundError:
    print("Model tidak ditemukan")
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-429-5b4d3ba34910> in <module>
#       1 model = None
#       2 try:
# ----> 3     model = pickle.load(open("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5", 'rb'))
#       4     print("Model ditemukan. Menggunakan model yang sudah ada . . .")
#       5 except FileNotFoundError:
#
# UnpicklingError: invalid load key, 'H'.

# %%
'''
if(not os.path.exists("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5")):
  print("Model belum dibuat sebelumnya")
else:
  print("Model sudah dibuat sebelumnya. Model akan dimuat sesaat lagi . . .")
  model = load_model(("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5")))
  print("Model dimuat")
'''
# Out:
# '\nif(not os.path.exists("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5")):\n  print("Model belum dibuat sebelumnya")\nelse:\n  print("Model sudah dibuat sebelumnya. Model akan dimuat sesaat lagi . . .")\n  model = load_model(("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5")))\n  print("Model dimuat")\n'

# %% [markdown]
# # Melakukan iterasi untuk melatih data dalam beberapa Epoch

# %%
import keras.backend.tensorflow_backend as tfback

print("tf.__version__ is", tf.__version__)
print("tf.keras.__version__ is:", tf.keras.__version__)

def _get_available_gpus():
    """Get a list of available gpu devices (formatted as strings).

    # Returns
        A list of available GPU devices.
    """
    #global _LOCAL_DEVICES
    if tfback._LOCAL_DEVICES is None:
        devices = tf.config.list_logical_devices()
        tfback._LOCAL_DEVICES = [x.name for x in devices]
    return [x for x in tfback._LOCAL_DEVICES if 'device:gpu' in x.lower()]

tfback._get_available_gpus = _get_available_gpus
# Out:
# tf.__version__ is 2.3.0
# tf.keras.__version__ is: 2.4.0

# %%
is_update_model = True
if model is None or is_update_model:
    from keras import backend as K
    print("Membuat Model ...")
    print("Mengecek ketersediaan GPU ...", K.tensorflow_backend._get_available_gpus())
    model = create_model()
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                       patience=40, min_delta=0.0001)
    
    mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
                          "best_model.h5"), monitor='val_loss', verbose=1,
                          save_best_only=True, save_weights_only=False, mode='min', period=1)

    #csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
    history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
                        shuffle=False, validation_data=(trim_dataset(x_val-1, BATCH_SIZE),
                        trim_dataset(y_val-1, BATCH_SIZE)), callbacks=[es, mcp])
    
    print("Menyimpan model . . .")
    #pickle.dump(model, open("./lstm_model", "wb"))
    model.save("C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes/best_model.h5")
# Out:
# Membuat Model ...
# Mengecek ketersediaan GPU ... []
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.00617, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 6s - loss: 0.0338 - accuracy: 9.1912e-04 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 2/200
#
# Epoch 00002: val_loss did not improve from 0.00617
# 17/17 - 6s - loss: 0.0513 - accuracy: 0.0000e+00 - val_loss: 0.0162 - val_accuracy: 0.0000e+00
# Epoch 3/200
#
# Epoch 00003: val_loss did not improve from 0.00617
# 17/17 - 8s - loss: 0.0405 - accuracy: 0.0018 - val_loss: 0.0172 - val_accuracy: 0.0000e+00
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 0.00617 to 0.00266, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 8s - loss: 0.0262 - accuracy: 0.0018 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 5/200
#
# Epoch 00005: val_loss did not improve from 0.00266
# 17/17 - 8s - loss: 0.0122 - accuracy: 0.0018 - val_loss: 0.1106 - val_accuracy: 0.0000e+00
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 0.00266
# 17/17 - 8s - loss: 0.0190 - accuracy: 0.0018 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 7/200
#
# Epoch 00007: val_loss improved from 0.00266 to 0.00264, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 8s - loss: 0.0140 - accuracy: 0.0018 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 8/200
#
# Epoch 00008: val_loss did not improve from 0.00264
# 17/17 - 8s - loss: 0.0049 - accuracy: 0.0018 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 9/200
#
# Epoch 00009: val_loss did not improve from 0.00264
# 17/17 - 8s - loss: 0.0066 - accuracy: 0.0018 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 10/200
#
# Epoch 00010: val_loss did not improve from 0.00264
# 17/17 - 9s - loss: 0.0075 - accuracy: 0.0018 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 11/200
#
# Epoch 00011: val_loss improved from 0.00264 to 0.00225, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0047 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 12/200
#
# Epoch 00012: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0047 - accuracy: 0.0018 - val_loss: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 13/200
#
# Epoch 00013: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0036 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 14/200
#
# Epoch 00014: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0039 - accuracy: 0.0018 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 15/200
#
# Epoch 00015: val_loss did not improve from 0.00225
# 17/17 - 10s - loss: 0.0041 - accuracy: 0.0018 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 16/200
#
# Epoch 00016: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0038 - accuracy: 0.0018 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 17/200
#
# Epoch 00017: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0030 - accuracy: 0.0018 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 18/200
#
# Epoch 00018: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0026 - accuracy: 0.0018 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 19/200
#
# Epoch 00019: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0024 - accuracy: 0.0018 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 20/200
#
# Epoch 00020: val_loss did not improve from 0.00225
# 17/17 - 9s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 21/200
#
# Epoch 00021: val_loss improved from 0.00225 to 0.00204, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 22/200
#
# Epoch 00022: val_loss improved from 0.00204 to 0.00203, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 23/200
#
# Epoch 00023: val_loss improved from 0.00203 to 0.00190, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 24/200
#
# Epoch 00024: val_loss did not improve from 0.00190
# 17/17 - 9s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 25/200
#
# Epoch 00025: val_loss improved from 0.00190 to 0.00182, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 26/200
#
# Epoch 00026: val_loss did not improve from 0.00182
# 17/17 - 9s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 27/200
#
# Epoch 00027: val_loss did not improve from 0.00182
# 17/17 - 9s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 28/200
#
# Epoch 00028: val_loss did not improve from 0.00182
# 17/17 - 9s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 29/200
#
# Epoch 00029: val_loss improved from 0.00182 to 0.00177, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 30/200
#
# Epoch 00030: val_loss did not improve from 0.00177
# 17/17 - 9s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 31/200
#
# Epoch 00031: val_loss did not improve from 0.00177
# 17/17 - 9s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 32/200
#
# Epoch 00032: val_loss did not improve from 0.00177
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 33/200
#
# Epoch 00033: val_loss improved from 0.00177 to 0.00177, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0024 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 34/200
#
# Epoch 00034: val_loss did not improve from 0.00177
# 17/17 - 9s - loss: 0.0023 - accuracy: 0.0018 - val_loss: 0.0054 - val_accuracy: 0.0000e+00
# Epoch 35/200
#
# Epoch 00035: val_loss did not improve from 0.00177
# 17/17 - 9s - loss: 0.0031 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 36/200
#
# Epoch 00036: val_loss did not improve from 0.00177
# 17/17 - 9s - loss: 0.0031 - accuracy: 0.0018 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 37/200
#
# Epoch 00037: val_loss improved from 0.00177 to 0.00148, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0034 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 38/200
#
# Epoch 00038: val_loss did not improve from 0.00148
# 17/17 - 9s - loss: 0.0032 - accuracy: 0.0018 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 39/200
#
# Epoch 00039: val_loss improved from 0.00148 to 0.00146, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0033 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 40/200
#
# Epoch 00040: val_loss did not improve from 0.00146
# 17/17 - 9s - loss: 0.0030 - accuracy: 0.0018 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 41/200
#
# Epoch 00041: val_loss improved from 0.00146 to 0.00142, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0034 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 42/200
#
# Epoch 00042: val_loss did not improve from 0.00142
# 17/17 - 9s - loss: 0.0031 - accuracy: 0.0018 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 43/200
#
# Epoch 00043: val_loss did not improve from 0.00142
# 17/17 - 9s - loss: 0.0026 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 44/200
#
# Epoch 00044: val_loss did not improve from 0.00142
# 17/17 - 9s - loss: 0.0023 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 45/200
#
# Epoch 00045: val_loss did not improve from 0.00142
# 17/17 - 9s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 46/200
#
# Epoch 00046: val_loss did not improve from 0.00142
# 17/17 - 9s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 47/200
#
# Epoch 00047: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 48/200
#
# Epoch 00048: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 49/200
#
# Epoch 00049: val_loss did not improve from 0.00142
# 17/17 - 9s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 50/200
#
# Epoch 00050: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 51/200
#
# Epoch 00051: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 52/200
#
# Epoch 00052: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 53/200
#
# Epoch 00053: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 54/200
#
# Epoch 00054: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 55/200
#
# Epoch 00055: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 56/200
#
# Epoch 00056: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 57/200
#
# Epoch 00057: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 58/200
#
# Epoch 00058: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.00142
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 60/200
#
# Epoch 00060: val_loss improved from 0.00142 to 0.00138, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.00138
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 62/200
#
# Epoch 00062: val_loss improved from 0.00138 to 0.00133, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 63/200
#
# Epoch 00063: val_loss did not improve from 0.00133
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 64/200
#
# Epoch 00064: val_loss improved from 0.00133 to 0.00130, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 65/200
#
# Epoch 00065: val_loss did not improve from 0.00130
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 66/200
#
# Epoch 00066: val_loss improved from 0.00130 to 0.00129, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 67/200
#
# Epoch 00067: val_loss did not improve from 0.00129
# 17/17 - 11s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 68/200
#
# Epoch 00068: val_loss improved from 0.00129 to 0.00126, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 11s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 69/200
#
# Epoch 00069: val_loss did not improve from 0.00126
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 70/200
#
# Epoch 00070: val_loss did not improve from 0.00126
# 17/17 - 11s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 71/200
#
# Epoch 00071: val_loss did not improve from 0.00126
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 72/200
#
# Epoch 00072: val_loss improved from 0.00126 to 0.00120, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 73/200
#
# Epoch 00073: val_loss did not improve from 0.00120
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 74/200
#
# Epoch 00074: val_loss did not improve from 0.00120
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 75/200
#
# Epoch 00075: val_loss did not improve from 0.00120
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0023 - val_accuracy: 0.0000e+00
# Epoch 76/200
#
# Epoch 00076: val_loss improved from 0.00120 to 0.00118, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 77/200
#
# Epoch 00077: val_loss did not improve from 0.00118
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 78/200
#
# Epoch 00078: val_loss improved from 0.00118 to 0.00116, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 79/200
#
# Epoch 00079: val_loss did not improve from 0.00116
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 80/200
#
# Epoch 00080: val_loss did not improve from 0.00116
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 81/200
#
# Epoch 00081: val_loss did not improve from 0.00116
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 82/200
#
# Epoch 00082: val_loss improved from 0.00116 to 0.00114, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 83/200
#
# Epoch 00083: val_loss did not improve from 0.00114
# 17/17 - 9s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 84/200
#
# Epoch 00084: val_loss did not improve from 0.00114
# 17/17 - 9s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 85/200
#
# Epoch 00085: val_loss did not improve from 0.00114
# 17/17 - 9s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 86/200
#
# Epoch 00086: val_loss did not improve from 0.00114
# 17/17 - 10s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 87/200
#
# Epoch 00087: val_loss did not improve from 0.00114
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 88/200
#
# Epoch 00088: val_loss improved from 0.00114 to 0.00112, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 89/200
#
# Epoch 00089: val_loss did not improve from 0.00112
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 90/200
#
# Epoch 00090: val_loss improved from 0.00112 to 0.00111, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 91/200
#
# Epoch 00091: val_loss did not improve from 0.00111
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 92/200
#
# Epoch 00092: val_loss improved from 0.00111 to 0.00109, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 93/200
#
# Epoch 00093: val_loss did not improve from 0.00109
# 17/17 - 9s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 94/200
#
# Epoch 00094: val_loss improved from 0.00109 to 0.00107, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 95/200
#
# Epoch 00095: val_loss did not improve from 0.00107
# 17/17 - 9s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 96/200
#
# Epoch 00096: val_loss improved from 0.00107 to 0.00103, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 97/200
#
# Epoch 00097: val_loss did not improve from 0.00103
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 98/200
#
# Epoch 00098: val_loss did not improve from 0.00103
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 99/200
#
# Epoch 00099: val_loss did not improve from 0.00103
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0028 - val_accuracy: 0.0000e+00
# Epoch 100/200
#
# Epoch 00100: val_loss did not improve from 0.00103
# 17/17 - 10s - loss: 0.0023 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 101/200
#
# Epoch 00101: val_loss did not improve from 0.00103
# 17/17 - 10s - loss: 0.0022 - accuracy: 0.0018 - val_loss: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 102/200
#
# Epoch 00102: val_loss improved from 0.00103 to 0.00101, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0025 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 103/200
#
# Epoch 00103: val_loss did not improve from 0.00101
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 104/200
#
# Epoch 00104: val_loss did not improve from 0.00101
# 17/17 - 10s - loss: 0.0024 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 105/200
#
# Epoch 00105: val_loss did not improve from 0.00101
# 17/17 - 10s - loss: 0.0020 - accuracy: 0.0018 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 106/200
#
# Epoch 00106: val_loss improved from 0.00101 to 0.00099, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0023 - accuracy: 0.0018 - val_loss: 9.9482e-04 - val_accuracy: 0.0000e+00
# Epoch 107/200
#
# Epoch 00107: val_loss did not improve from 0.00099
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 108/200
#
# Epoch 00108: val_loss improved from 0.00099 to 0.00098, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 9.8387e-04 - val_accuracy: 0.0000e+00
# Epoch 109/200
#
# Epoch 00109: val_loss did not improve from 0.00098
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 110/200
#
# Epoch 00110: val_loss improved from 0.00098 to 0.00098, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 9.8008e-04 - val_accuracy: 0.0000e+00
# Epoch 111/200
#
# Epoch 00111: val_loss did not improve from 0.00098
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 112/200
#
# Epoch 00112: val_loss did not improve from 0.00098
# 17/17 - 10s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 113/200
#
# Epoch 00113: val_loss did not improve from 0.00098
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 114/200
#
# Epoch 00114: val_loss improved from 0.00098 to 0.00094, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0018 - accuracy: 0.0018 - val_loss: 9.4204e-04 - val_accuracy: 0.0000e+00
# Epoch 115/200
#
# Epoch 00115: val_loss did not improve from 0.00094
# 17/17 - 10s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 116/200
#
# Epoch 00116: val_loss improved from 0.00094 to 0.00094, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 9.4049e-04 - val_accuracy: 0.0000e+00
# Epoch 117/200
#
# Epoch 00117: val_loss did not improve from 0.00094
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 118/200
#
# Epoch 00118: val_loss did not improve from 0.00094
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 9.4060e-04 - val_accuracy: 0.0000e+00
# Epoch 119/200
#
# Epoch 00119: val_loss did not improve from 0.00094
# 17/17 - 10s - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 120/200
#
# Epoch 00120: val_loss did not improve from 0.00094
# 17/17 - 10s - loss: 0.0013 - accuracy: 0.0018 - val_loss: 9.4087e-04 - val_accuracy: 0.0000e+00
# Epoch 121/200
#
# Epoch 00121: val_loss did not improve from 0.00094
# 17/17 - 9s - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 122/200
#
# Epoch 00122: val_loss improved from 0.00094 to 0.00094, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0014 - accuracy: 0.0018 - val_loss: 9.3618e-04 - val_accuracy: 0.0000e+00
# Epoch 123/200
#
# Epoch 00123: val_loss did not improve from 0.00094
# 17/17 - 9s - loss: 0.0012 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 124/200
#
# Epoch 00124: val_loss improved from 0.00094 to 0.00093, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0014 - accuracy: 0.0018 - val_loss: 9.2708e-04 - val_accuracy: 0.0000e+00
# Epoch 125/200
#
# Epoch 00125: val_loss did not improve from 0.00093
# 17/17 - 10s - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 126/200
#
# Epoch 00126: val_loss improved from 0.00093 to 0.00091, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 9.1188e-04 - val_accuracy: 0.0000e+00
# Epoch 127/200
#
# Epoch 00127: val_loss did not improve from 0.00091
# 17/17 - 10s - loss: 0.0014 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 128/200
#
# Epoch 00128: val_loss improved from 0.00091 to 0.00089, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 8.8649e-04 - val_accuracy: 0.0000e+00
# Epoch 129/200
#
# Epoch 00129: val_loss did not improve from 0.00089
# 17/17 - 10s - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 130/200
#
# Epoch 00130: val_loss did not improve from 0.00089
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 8.9059e-04 - val_accuracy: 0.0000e+00
# Epoch 131/200
#
# Epoch 00131: val_loss did not improve from 0.00089
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 132/200
#
# Epoch 00132: val_loss improved from 0.00089 to 0.00088, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 11s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 8.8180e-04 - val_accuracy: 0.0000e+00
# Epoch 133/200
#
# Epoch 00133: val_loss did not improve from 0.00088
# 17/17 - 11s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 134/200
#
# Epoch 00134: val_loss improved from 0.00088 to 0.00087, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 8.6523e-04 - val_accuracy: 0.0000e+00
# Epoch 135/200
#
# Epoch 00135: val_loss did not improve from 0.00087
# 17/17 - 10s - loss: 0.0013 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 136/200
#
# Epoch 00136: val_loss did not improve from 0.00087
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 8.8710e-04 - val_accuracy: 0.0000e+00
# Epoch 137/200
#
# Epoch 00137: val_loss did not improve from 0.00087
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 138/200
#
# Epoch 00138: val_loss did not improve from 0.00087
# 17/17 - 10s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 8.9632e-04 - val_accuracy: 0.0000e+00
# Epoch 139/200
#
# Epoch 00139: val_loss did not improve from 0.00087
# 17/17 - 10s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 140/200
#
# Epoch 00140: val_loss improved from 0.00087 to 0.00084, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 8.3752e-04 - val_accuracy: 0.0000e+00
# Epoch 141/200
#
# Epoch 00141: val_loss did not improve from 0.00084
# 17/17 - 9s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 142/200
#
# Epoch 00142: val_loss did not improve from 0.00084
# 17/17 - 10s - loss: 0.0016 - accuracy: 0.0018 - val_loss: 8.5139e-04 - val_accuracy: 0.0000e+00
# Epoch 143/200
#
# Epoch 00143: val_loss did not improve from 0.00084
# 17/17 - 10s - loss: 0.0015 - accuracy: 0.0018 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 144/200
#
# Epoch 00144: val_loss did not improve from 0.00084
# 17/17 - 10s - loss: 0.0019 - accuracy: 0.0018 - val_loss: 8.8829e-04 - val_accuracy: 0.0000e+00
# Epoch 145/200
#
# Epoch 00145: val_loss did not improve from 0.00084
# 17/17 - 10s - loss: 0.0017 - accuracy: 0.0018 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 146/200
#
# Epoch 00146: val_loss improved from 0.00084 to 0.00081, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BMRI/outputs/lstmiter_changes\best_model.h5
# 17/17 - 9s - loss: 0.0021 - accuracy: 0.0018 - val_loss: 8.0596e-04 - val_accuracy: 0.0000e+00
# Epoch 147/200

# %% [markdown]
# # Melakukan Prediksi

# %% [markdown]
# Setelah data berhasil dilatih dengan model yang sudah dibuat, maka selanjutnya adalah proses prediksi

# %% [markdown]
# ## Prediksi dengan data yang masih Normal

# %%
# Melakukan Prediksi dengan model yang sudah dibuat
y_pred = model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)

# Menampilkan nilai Error menggunakan MSE
print("Besarnya nilai Error : ", error, y_pred.shape, y_test_t.shape)
# Out:
# Besarnya nilai Error :  0.0006700163488515545 (128,) (128,)

# %% [markdown]
# ## Proses Denormalisasi data hasil prediksi

# %%
# Melakukan De-normalisasi data output untuk data uji dan data validasi
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]

# %% [markdown]
# # Visualisasi data output

# %% [markdown]
# ## Visualisasi nilai Loss yang dihasilkan

# %%
# Visualisasi model Loss dari data uji dan data validasi
from matplotlib import pyplot as plt
plt.figure(figsize=[12,6])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(BATCH_SIZE)+"_"+'.png'))

# %%
# Menyimpan model
#saved_model = load_model(os.path.join(OUTPUT_PATH, '/content/drive/My Drive/TA_LSTM/outputs/best_model.h5')) 
saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) 
print(saved_model)
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x000002D4381B6760>

# %%
y_pred = saved_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Nilai Error dari MSE sebesar ", error, y_pred.shape, y_test_t.shape)
print("Harga prediksi esok hari sebelum denormalisasi :",y_pred[0])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] 
print("Harga prediksi esok hari sesudah denormalisasi :",y_pred_org[0])
# Out:
# Nilai Error dari MSE sebesar  0.0004672058007397189 (128,) (128,)
# Harga prediksi esok hari sebelum denormalisasi : 0.4175425
# Harga prediksi esok hari sesudah denormalisasi : 5841.1157

# %% [markdown]
# # Visualisasi hasil prediksi

# %%
kurang = y_pred_org - y_test_t_org
kurang_table = pd.DataFrame(kurang, columns=['hasil pengurangan uji dgn validasi'])
kurang_table.to_csv ('outputs/Hasil-pengurangan.csv', index = None, header=True)

# %%
# Visualisasi hasil prediksi dengan model yang sudah dibuat
from matplotlib import pyplot as plt
plt.figure(figsize=[12,6])
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Nilai Prediksi Pergerakan Harga Saham pada PT Bank Mandiri Tbk')
plt.ylabel('Price (IDR)')
plt.xlabel('Validation Days')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.legend(['Prediction', 'Real'], loc='lower left')
plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(BATCH_SIZE)+"_"+'.png'))
print_time("Program selesai pada ", stime)
# Out:
# Program selesai pada  1.0 menit :  0.0 detik

# %% [markdown]
# # Evaluasi Model yang sudah dibuat

# %%
# Evaluasi model
score = model.evaluate(x_t, y_t, batch_size=BATCH_SIZE)
print('Test loss:', score[0])
print('Test accuracy:', "{:%}".format(score[1]))
# Out:
# 37/37 [==============================] - 0s 3ms/step - loss: 8.1706e-04 - accuracy: 0.0017
# Test loss: 0.0008170589571818709
# Test accuracy: 0.168919%

# %% [markdown]
# # Menyimpan hasil prediksi ke dalam csv

# %%
# Menyimpan hasil data prediksi ke dalam bentuk Dataframe
pred_table = pd.DataFrame(y_pred_org, columns=['Close'])

# Melakukan Ekspor data menjadi bentuk CSV
export_csv = pred_table.to_csv (r'/content/drive/My Drive/TA_LSTM/outputs/Prediksi Close Price.csv', index = None, header=True) 
print ("Dokumen CSV sudah tersimpan di direktori", OUTPUT_PATH)
# Out:
# Dokumen CSV sudah tersimpan di direktori C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes

# %%
# Menggabungkan dataset dengan data lama
df_close = df.drop(columns=['Date','Open', 'High', 'Low', 'Adj Close', 'Volume'])
df_new = pd.concat([df_close, pred_table], ignore_index=True, sort=True)

# Menyimpan dataset baru
export_csv = df_new.to_csv(r'/content/drive/My Drive/TA_LSTM/outputs/Dataset baru.csv', index = None, header=True) 
print ("Dokumen CSV sudah tersimpan di direktori", OUTPUT_PATH)
# Out:
# Dokumen CSV sudah tersimpan di direktori C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes
