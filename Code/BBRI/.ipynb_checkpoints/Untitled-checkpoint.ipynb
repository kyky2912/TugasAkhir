# %% [markdown]
# # Melakukan Prediksi dengan menggunakan model LSTM

# %% [markdown]
# Model LSTM (Long Short Term Memory) merupakan Deep Neural Network yang mampu melakukan prediksi pergerakan saham ataupun jenis prediksi lainnya. Untuk menggunakan model ini, ada beberapa hal yang harus diperlukan, yaitu :
#
# Membuat data generator
# Sebelum membuat data generator, data harus dibersihkan dan dilakukan Pre-processing
# Menentukan hyperparameter yang tepat untuk meminimalisir nilai Error
# Untuk menentukan nilai hyperparameter yang tepat, dapat dilihat
# Melakukan visualisasi dan evaluasi
# Menganalisa secara teknikal yang bisa dilihat

# %% [markdown]
# # Membersihkan Data dan melakukan Pre-Processing

# %% [markdown]
# ## Library yang digunakan

# %% [markdown]
# Tahap awal adalah menentukan dan mendownload library yang akan digunakan. Di bawah ini adalah library - library yang akan digunakan dalam penelitian ini

# %%
# Numpy untuk formatting number atau array
import numpy as np

# Pandas untuk membuat DataFrame dan membaca dokumen csv
import pandas as pd 

# Tensorflow dan Keras sebagai Framework dan Backend
import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger, Callback
from tensorflow.keras import optimizers

# Sklearn sebagai komponen machine learning, untuk normalisasi, membagi dataset dan menghitung nilai error
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Logging untuk mencatat tiap aktivitas yang dilakukan sistem
import logging

# Pickle untuk mengambil model jika sudah dibuat sebelumnya
import pickle

# OS untuk operation system, sys untuk system, time untuk waktu, tqdm notebook untuk notebook jika dibuat selain google colab
import os
import sys
import time
from tqdm.notebook import tqdm_notebook
# Out:
# Using TensorFlow backend.

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
logging.getLogger("tensorflow").setLevel(logging.ERROR)
os.environ['TZ'] = 'Asia/Jakarta'  # to set timezone; needed when running on cloud
time.localtime()
# Out:
# time.struct_time(tm_year=2022, tm_mon=4, tm_mday=6, tm_hour=12, tm_min=41, tm_sec=55, tm_wday=2, tm_yday=96, tm_isdst=0)

# %% [markdown]
# Dataset yang digunakan berupa Historical Data Price PT BBRI Tbk sejak 2011 sampai 2021

# %%
# Reading The Data
data = pd.read_csv('inputs/BBRI.JK.csv', index_col='Date', parse_dates = True)

# %%
params = {
    "batch_size": 20, 
    "epochs": 200,
    "lr": 0.0001,
    "time_steps": 50
}
iter_changes = "dropout_layers_0.4_0.4"

# %%
INPUT_PATH = "C:/Users/HP/Desktop/Nicky-Skripsi/ProgramSkripsiFix/BBRI"+"/inputs"
OUTPUT_PATH = "C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstm"+"iter_changes"
TIME_STEPS = params["time_steps"]
BATCH_SIZE = params["batch_size"]
stime = time.time()

# %%
if not os.path.exists(OUTPUT_PATH):
  os.makedirs(OUTPUT_PATH)
  print("Direktori output dibuat di ", OUTPUT_PATH)
else:
  print("Direktori sudah dibuat sebelumnya")
# Out:
# Direktori sudah dibuat sebelumnya

# %%
stime = time.time()
print(os.listdir(INPUT_PATH))

# Membaca Dataset
df = pd.read_csv(os.path.join(INPUT_PATH, "BBRI.JK.csv"), engine='python')
df = df.dropna()
df = df.reset_index(drop=True)
print(df.shape)
print(df.columns)
display(df.head(5))

# Menampilkan Feature dan Tipe Data yang digunakan
print("\n Tipe data pada Fitur yang digunakan :")
print(df.dtypes)

# Mendefinisikan variable baru untuk menampung Feature
train_cols = ["Open","High","Low","Close","Volume"]

# Membagi dataset menjadi 80% untuk Data Latih dan 20% untuk Data Uji
df_train, df_test = train_test_split(df, train_size=0.8, test_size=0.2, shuffle=False)
print("\nBanyaknya Data Latih : ", len(df_train))
print("Banyaknya Data Uji : ", len(df_test))
# Out:
# ['BBRI.JK.csv']
# (2689, 7)
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')
#          Date    Open    High     Low   Close   Adj Close       Volume
# 0  2011-01-03  1035.0  1075.0  1020.0  1035.0  793.864746  126655000.0
# 1  2011-01-04  1030.0  1055.0  1010.0  1030.0  790.029602  278485000.0
# 2  2011-01-05  1060.0  1065.0  1010.0  1060.0  813.040222  237990000.0
# 3  2011-01-06  1035.0  1070.0  1015.0  1035.0  793.864746  216545000.0
# 4  2011-01-07   980.0  1025.0   970.0   980.0  751.678711  604570000.0
#  Tipe data pada Fitur yang digunakan :
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object
#
# Banyaknya Data Latih :  2151
# Banyaknya Data Uji :  538

# %%
# Split skip 2 hari untuk prediksi tanggal 4, dimulai dari tanggal 2 januari, 27 desember dll
df2 = df.iloc[::2]
df2_train, df2_test = train_test_split(df2, train_size=0.8, test_size=0.2, shuffle=False)
print("\nBanyaknya Data Latih : ", len(df2_train))
print("Banyaknya Data Uji : ", len(df2_test))
df2.tail()
# Out:
# Banyaknya Data Latih :  1076
# Banyaknya Data Uji :  269
#             Date    Open    High     Low   Close  Adj Close       Volume
# 2680  2021-10-18  4350.0  4410.0  4340.0  4410.0     4410.0  286829000.0
# 2682  2021-10-21  4450.0  4460.0  4320.0  4360.0     4360.0  319230200.0
# 2684  2021-10-25  4330.0  4370.0  4300.0  4300.0     4300.0  128240100.0
# 2686  2021-10-27  4330.0  4340.0  4260.0  4290.0     4290.0  258038300.0
# 2688  2021-10-29  4300.0  4300.0  4220.0  4250.0     4250.0  155011100.0

# %%
# Split skip 2 hari untuk prediksi tanggal 5, dimulai dari tanggal 3 januari, 30 desember dll
df3 = df.iloc[1::2]
df3_train, df3_test = train_test_split(df3, train_size=0.8, test_size=0.2, shuffle=False)
print("\nBanyaknya Data Latih : ", len(df3_train))
print("Banyaknya Data Uji : ", len(df3_test))
df3.tail()
# Out:
# Banyaknya Data Latih :  1075
# Banyaknya Data Uji :  269
#             Date    Open    High     Low   Close  Adj Close       Volume
# 2679  2021-10-15  4250.0  4330.0  4220.0  4320.0     4320.0  318189600.0
# 2681  2021-10-19  4450.0  4450.0  4360.0  4400.0     4400.0  161256300.0
# 2683  2021-10-22  4340.0  4400.0  4320.0  4400.0     4400.0  160459300.0
# 2685  2021-10-26  4280.0  4370.0  4270.0  4350.0     4350.0  108782400.0
# 2687  2021-10-28  4210.0  4300.0  4200.0  4240.0     4240.0  159645200.0

# %% [markdown]
# ##  Visualisasi terhadap dataset

# %% [markdown]
# Visualisasi ini bertujuan untuk mengetahui OHLC (Open, High, Low, Close) dengan menampilkan nya berbentuk grafik candle stick

# %%
import plotly.graph_objects as go
import pandas as pd
from datetime import datetime

fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                open=df['Open'],
                high=df['High'],
                low=df['Low'],
                close=df['Close'])])
fig.show()
# Out:
# <div>                            <div id="5dcb5a9d-f634-406f-800b-04017a5baf3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5dcb5a9d-f634-406f-800b-04017a5baf3b")) {                    Plotly.newPlot(                        "5dcb5a9d-f634-406f-800b-04017a5baf3b",                        [{"close":[1035.0,1030.0,1060.0,1035.0,980.0,930.0,960.0,1000.0,1020.0,1030.0,1010.0,1000.0,960.0,955.0,940.0,975.0,1030.0,1060.0,1050.0,1020.0,970.0,980.0,985.0,980.0,975.0,965.0,925.0,910.0,920.0,930.0,950.0,960.0,975.0,980.0,950.0,960.0,930.0,945.0,940.0,980.0,980.0,985.0,1050.0,1060.0,1030.0,1030.0,1030.0,1030.0,1050.0,1020.0,1020.0,1010.0,1000.0,1020.0,1040.0,1050.0,1060.0,1070.0,1070.0,1070.0,1080.0,1150.0,1170.0,1160.0,1150.0,1190.0,1240.0,1260.0,1230.0,1230.0,1240.0,1220.0,1230.0,1250.0,1250.0,1320.0,1300.0,1300.0,1290.0,1310.0,1310.0,1290.0,1310.0,1290.0,1280.0,1260.0,1240.0,1220.0,1230.0,1260.0,1240.0,1250.0,1230.0,1270.0,1310.0,1310.0,1250.0,1240.0,1230.0,1250.0,1250.0,1280.0,1270.0,1250.0,1300.0,1270.0,1280.0,1280.0,1260.0,1260.0,1250.0,1260.0,1280.0,1230.0,1240.0,1250.0,1270.0,1270.0,1270.0,1290.0,1280.0,1280.0,1300.0,1340.0,1340.0,1340.0,1320.0,1330.0,1360.0,1370.0,1350.0,1350.0,1350.0,1350.0,1340.0,1330.0,1330.0,1330.0,1330.0,1320.0,1330.0,1380.0,1360.0,1380.0,1440.0,1450.0,1440.0,1420.0,1330.0,1300.0,1260.0,1310.0,1290.0,1300.0,1320.0,1340.0,1370.0,1280.0,1270.0,1290.0,1280.0,1300.0,1310.0,1330.0,1330.0,1370.0,1390.0,1370.0,1320.0,1280.0,1230.0,1260.0,1290.0,1230.0,1240.0,1220.0,1060.0,1120.0,1070.0,1150.0,1180.0,1180.0,1170.0,1060.0,1060.0,1080.0,1190.0,1160.0,1210.0,1250.0,1290.0,1290.0,1310.0,1340.0,1280.0,1290.0,1260.0,1260.0,1300.0,1300.0,1330.0,1350.0,1360.0,1350.0,1310.0,1340.0,1320.0,1360.0,1370.0,1370.0,1410.0,1380.0,1370.0,1390.0,1380.0,1390.0,1360.0,1330.0,1300.0,1340.0,1330.0,1330.0,1310.0,1280.0,1300.0,1300.0,1300.0,1340.0,1350.0,1330.0,1340.0,1350.0,1340.0,1340.0,1310.0,1320.0,1300.0,1360.0,1360.0,1380.0,1400.0,1370.0,1370.0,1370.0,1340.0,1350.0,1350.0,1360.0,1380.0,1390.0,1390.0,1380.0,1400.0,1410.0,1400.0,1380.0,1370.0,1360.0,1390.0,1410.0,1430.0,1410.0,1400.0,1390.0,1400.0,1400.0,1380.0,1370.0,1410.0,1420.0,1430.0,1400.0,1370.0,1430.0,1390.0,1330.0,1370.0,1340.0,1330.0,1350.0,1360.0,1360.0,1380.0,1390.0,1370.0,1360.0,1330.0,1330.0,1380.0,1340.0,1330.0,1330.0,1320.0,1290.0,1280.0,1290.0,1330.0,1350.0,1360.0,1360.0,1360.0,1360.0,1340.0,1350.0,1360.0,1350.0,1360.0,1380.0,1400.0,1390.0,1410.0,1410.0,1400.0,1400.0,1380.0,1380.0,1380.0,1400.0,1400.0,1410.0,1400.0,1390.0,1390.0,1390.0,1400.0,1380.0,1380.0,1390.0,1340.0,1330.0,1330.0,1330.0,1310.0,1310.0,1300.0,1320.0,1300.0,1290.0,1290.0,1230.0,1240.0,1200.0,1170.0,1190.0,1190.0,1190.0,1160.0,1160.0,1170.0,1180.0,1130.0,1100.0,1050.0,1070.0,1190.0,1180.0,1180.0,1230.0,1210.0,1210.0,1190.0,1190.0,1200.0,1190.0,1220.0,1210.0,1190.0,1210.0,1210.0,1240.0,1240.0,1270.0,1270.0,1310.0,1310.0,1330.0,1340.0,1330.0,1340.0,1340.0,1310.0,1310.0,1320.0,1310.0,1320.0,1330.0,1310.0,1280.0,1270.0,1270.0,1270.0,1340.0,1360.0,1400.0,1390.0,1380.0,1400.0,1380.0,1360.0,1390.0,1410.0,1440.0,1430.0,1420.0,1420.0,1430.0,1460.0,1460.0,1460.0,1460.0,1420.0,1370.0,1390.0,1420.0,1410.0,1420.0,1450.0,1470.0,1470.0,1480.0,1480.0,1460.0,1480.0,1460.0,1440.0,1440.0,1440.0,1450.0,1450.0,1470.0,1470.0,1490.0,1490.0,1480.0,1490.0,1500.0,1490.0,1480.0,1480.0,1540.0,1520.0,1500.0,1500.0,1530.0,1510.0,1540.0,1560.0,1550.0,1540.0,1530.0,1500.0,1510.0,1500.0,1530.0,1480.0,1440.0,1430.0,1420.0,1410.0,1450.0,1450.0,1450.0,1440.0,1440.0,1450.0,1440.0,1440.0,1430.0,1420.0,1410.0,1450.0,1430.0,1430.0,1440.0,1410.0,1410.0,1420.0,1420.0,1430.0,1410.0,1410.0,1410.0,1440.0,1440.0,1400.0,1400.0,1380.0,1390.0,1380.0,1390.0,1390.0,1390.0,1390.0,1410.0,1440.0,1470.0,1480.0,1500.0,14 ...

# %% [markdown]
# # Melakukan Normalisasi data

# %% [markdown]
# Normalisasi data dilakukan untuk memudahkan melakukan prediksi. Normalisasi yang digunakan berupa MinMaxScaller.

# %%
# Melakukan Normalisasi untuk Data Latih dan Data Uji
x = df_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x_train = min_max_scaler.fit_transform(x)
x_test = min_max_scaler.transform(df_test.loc[:,train_cols])

# %%
# Melakukan Normalisasi untuk Data Latih dan Data Uji
x2 = df2_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x2_train = min_max_scaler.fit_transform(x2)
x2_test = min_max_scaler.transform(df2_test.loc[:,train_cols])

# %%
# Melakukan Normalisasi untuk Data Latih dan Data Uji
x3 = df3_train.loc[:,train_cols].values
min_max_scaler = MinMaxScaler()
x3_train = min_max_scaler.fit_transform(x3)
x3_test = min_max_scaler.transform(df3_test.loc[:,train_cols])

# %% [markdown]
# # Menghapus data yang tidak diperlukan

# %%
print("Menghapus dataframe yang tidak terpakai . . .")
apus  = (sys.getsizeof(df)+sys.getsizeof(df_train)+sys.getsizeof(df_test))//1024
print ("Dataframe terhapus sebesar ", apus ," KB")
del df_test
del df_train
del x
print ("Proses penghapusan selesai")
# Out:
# Menghapus dataframe yang tidak terpakai . . .
# Dataframe terhapus sebesar  625  KB
# Proses penghapusan selesai

# %%
print("Menghapus dataframe yang tidak terpakai . . .")
apus  = (sys.getsizeof(df2)+sys.getsizeof(df2_train)+sys.getsizeof(df2_test))//1024
print ("Dataframe terhapus sebesar ", apus ," KB")
del df2_test
del df2_train
del x2
print ("Proses penghapusan selesai")
# Out:
# Menghapus dataframe yang tidak terpakai . . .
# Dataframe terhapus sebesar  312  KB
# Proses penghapusan selesai

# %%
print("Menghapus dataframe yang tidak terpakai . . .")
apus  = (sys.getsizeof(df3)+sys.getsizeof(df3_train)+sys.getsizeof(df3_test))//1024
print ("Dataframe terhapus sebesar ", apus ," KB")
del df3_test
del df3_train
del x3
print ("Proses penghapusan selesai")
# Out:
# Menghapus dataframe yang tidak terpakai . . .
# Dataframe terhapus sebesar  312  KB
# Proses penghapusan selesai

# %% [markdown]
# # Proses Data Generator untuk Model LSTM

# %% [markdown]
# Proses ini terdiri dari beberapa step, yaitu :
#
# Memangkas dataset
# Membuat time series

# %% [markdown]
# ## Memangkas Dataset

# %% [markdown]
# Pemangkasan ini bertujuan untuk membuang data yang tidak diperlukan

# %%
def print_time(text, stime):
    seconds = (time.time()-stime)
    print(text, seconds//60,"menit : ",np.round(seconds%60),"detik")

# %%
def trim_dataset(mat,batch_size):
    no_of_rows_drop = mat.shape[0]%batch_size
    if no_of_rows_drop > 0:
        return mat[:-no_of_rows_drop]
    else:
        return mat

# %% [markdown]
# ## Membuat Time Series

# %% [markdown]
# Hal ini dilakukan untuk mengubah dimensi dari dataset, yang semula 2 dimensi, menjadi 3 dimensi. Dimensi tersebut adalah input data, jumlah data yang akan dijadikan ukuran untuk back-forward dan feature yang digunakan

# %%
def build_timeseries(mat, y_col_index):
    dim_0 = mat.shape[0] - TIME_STEPS
    dim_1 = mat.shape[1]
    x = np.zeros((dim_0, TIME_STEPS, dim_1))
    y = np.zeros((dim_0,))
    print("dim_0",dim_0)
    for i in tqdm_notebook(range(dim_0)):
        x[i] = mat[i:TIME_STEPS+i]
        y[i] = mat[TIME_STEPS+i, y_col_index]
    print("Ukuran time-series untuk Input dan Output : ",x.shape,y.shape)
    return x, y

# %%
# Pengecekan data yang masih null
print("Apa masih ada data yang berisikan null?",np.isnan(x_train).any(), np.isnan(x_train).any())
x_t, y_t = build_timeseries(x_train, 3)
x_t = trim_dataset(x_t, BATCH_SIZE)
y_t = trim_dataset(y_t, BATCH_SIZE)
print("Data yang sudah dipangkas menjadi : ",x_t.shape, y_t.shape)
# Out:
# Apa masih ada data yang berisikan null? False False
# dim_0 2101
#   0%|          | 0/2101 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (2101, 50, 5) (2101,)
# Data yang sudah dipangkas menjadi :  (2100, 50, 5) (2100,)

# %%
# Pengecekan data yang masih null
print("Apa masih ada data yang berisikan null?",np.isnan(x2_train).any(), np.isnan(x2_train).any())
x2_t, y2_t = build_timeseries(x2_train, 3)
x2_t = trim_dataset(x2_t, BATCH_SIZE)
y2_t = trim_dataset(y2_t, BATCH_SIZE)
print("Data yang sudah dipangkas menjadi : ",x2_t.shape, y2_t.shape)
# Out:
# Apa masih ada data yang berisikan null? False False
# dim_0 1026
#   0%|          | 0/1026 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (1026, 50, 5) (1026,)
# Data yang sudah dipangkas menjadi :  (1020, 50, 5) (1020,)

# %%
# Pengecekan data yang masih null
print("Apa masih ada data yang berisikan null?",np.isnan(x3_train).any(), np.isnan(x3_train).any())
x3_t, y3_t = build_timeseries(x3_train, 3)
x3_t = trim_dataset(x3_t, BATCH_SIZE)
y3_t = trim_dataset(y3_t, BATCH_SIZE)
print("Data yang sudah dipangkas menjadi : ",x3_t.shape, y3_t.shape)
# Out:
# Apa masih ada data yang berisikan null? False False
# dim_0 1025
#   0%|          | 0/1025 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (1025, 50, 5) (1025,)
# Data yang sudah dipangkas menjadi :  (1020, 50, 5) (1020,)

# %%
# Membuat Time-Series dari data uji
x_temp, y_temp = build_timeseries(x_test, 3)
x_val, x_test_t = np.split(trim_dataset(x_temp, BATCH_SIZE),2)
y_val, y_test_t = np.split(trim_dataset(y_temp, BATCH_SIZE),2)
# Out:
# dim_0 488
#   0%|          | 0/488 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (488, 50, 5) (488,)

# %%
# Membuat Time-Series dari data uji
x2_temp, y2_temp = build_timeseries(x2_test, 3)
x2_val, x2_test_t = np.split(trim_dataset(x2_temp, BATCH_SIZE),2)
y2_val, y2_test_t = np.split(trim_dataset(y2_temp, BATCH_SIZE),2)
# Out:
# dim_0 219
#   0%|          | 0/219 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (219, 50, 5) (219,)

# %%
# Membuat Time-Series dari data uji
x3_temp, y3_temp = build_timeseries(x3_test, 3)
x3_val, x3_test_t = np.split(trim_dataset(x3_temp, BATCH_SIZE),2)
y3_val, y3_test_t = np.split(trim_dataset(y3_temp, BATCH_SIZE),2)
# Out:
# dim_0 219
#   0%|          | 0/219 [00:00<?, ?it/s]
# Ukuran time-series untuk Input dan Output :  (219, 50, 5) (219,)

# %%
print("Banyaknya ukuran data validasi :", x_val.shape, y_val.shape)
# Out:
# Banyaknya ukuran data validasi : (240, 50, 5) (240,)

# %%
print("Banyaknya ukuran data validasi :", x2_val.shape, y2_val.shape)
# Out:
# Banyaknya ukuran data validasi : (100, 50, 5) (100,)

# %%
print("Banyaknya ukuran data validasi :", x3_val.shape, y3_val.shape)
# Out:
# Banyaknya ukuran data validasi : (100, 50, 5) (100,)

# %% [markdown]
# # Membuat model LSTM

# %% [markdown]
# Pembuatan model ini tidak terlepas dari hyperparameter yang digunakan, banyanya sel LSTM yang dibuat dan banyaknya hidden layer yang dibuat

# %%
def create_model():
    lstm_model = Sequential()
    # (batch_size, timesteps, data_dim)
    lstm_model.add(LSTM(256, batch_input_shape=(BATCH_SIZE, TIME_STEPS, x_t.shape[2]),
                        dropout=0.0, recurrent_dropout=0.0, stateful=True, return_sequences=True,
                        kernel_initializer='random_uniform'))
    lstm_model.add(Dropout(0.2))
    lstm_model.add(LSTM(256, dropout=0.2))
    lstm_model.add(Dropout(0.2))
    lstm_model.add(Dense(128,activation='tanh'))
    lstm_model.add(Dense(1,activation='sigmoid'))
    #optimizer = optimizers.RMSprop(lr=params["lr"])
    optimizer = tf.keras.optimizers.Adam(lr=params["lr"], beta_1=0.9, beta_2=0.999, amsgrad=False, epsilon=None) # ini yg paling optimal
    # optimizer = optimizers.SGD(lr=0.000001, decay=1e-6, momentum=0.9, nesterov=True)
    lstm_model.compile(loss='mean_squared_error', optimizer=optimizer, metrics=['accuracy'])
    return lstm_model

# %% [markdown]
# def create_model(sequence_length, n_features, units=256, cell=LSTM, n_layers=2, dropout=0.3,
#                 loss="mean_absolute_error", optimizer="adam", bidirectional=False):
#     lstm_model = Sequential()
#     for i in range(n_layers):
#         if i == 0:
#             if bidirectional:
#                 lstm_model.add(Bidirectional(cell(units, return_sequences=True), batch_input_shape=(None, sequence_length, n_features)))
#             else:
#                 lstm_model.add(cell(units, return_sequences=True, batch_input_shape=(None, sequence_length, n_features)))
#         elif i == n_layers - 1:
#             if bidirectional:
#                 lstm_model.add(Bidirectional(cell(units, return_sequences=False)))
#             else:
#                 lstm_model.add(cell(units, return_sequences=False))
#         else:
#             if bidirectional:
#                 lstm_model.add(Bidirectional(cell(units, return_sequences=True)))
#             else:
#                 lstm_model.add(cell(units, return_sequences=True))
#         lstm_model.add(Dropout(dropout))
#     lstm_model.add(Dense(1, activation="linear"))
#     lstm_model.compile(loss=loss, metrics=["mean_absolute_error"], optimizer=optimizer)
#     return lstm_model

# %%
model = None
try:
    model = pickle.load(open("C:/Users/HP/Desktop/Nicky-Skripsi/Program2/lstm_model", 'rb'))
    print("Model ditemukan. Menggunakan model yang sudah ada . . .")
except FileNotFoundError:
    print("Model tidak ditemukan")
# Out:
# Model tidak ditemukan

# %%
'''
if(not os.path.exists("C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes/best_model.h5")):
  print("Model belum dibuat sebelumnya")
else:
  print("Model sudah dibuat sebelumnya. Model akan dimuat sesaat lagi . . .")
  model = load_model("C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes/best_model.h5")
  print("Model dimuat")
'''
# Out:
# '\nif(not os.path.exists("C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes/best_model.h5")):\n  print("Model belum dibuat sebelumnya")\nelse:\n  print("Model sudah dibuat sebelumnya. Model akan dimuat sesaat lagi . . .")\n  model = load_model("C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes/best_model.h5")\n  print("Model dimuat")\n'

# %% [markdown]
# # Melakukan iterasi untuk melatih data dalam beberapa Epoch

# %%
import keras.backend.tensorflow_backend as tfback

print("tf.__version__ is", tf.__version__)
print("tf.keras.__version__ is:", tf.keras.__version__)

def _get_available_gpus():
    """Get a list of available gpu devices (formatted as strings).

    # Returns
        A list of available GPU devices.
    """
    #global _LOCAL_DEVICES
    if tfback._LOCAL_DEVICES is None:
        devices = tf.config.list_logical_devices()
        tfback._LOCAL_DEVICES = [x.name for x in devices]
    return [x for x in tfback._LOCAL_DEVICES if 'device:gpu' in x.lower()]

tfback._get_available_gpus = _get_available_gpus
# Out:
# tf.__version__ is 2.3.0
# tf.keras.__version__ is: 2.4.0

# %%
is_update_model = True
if model is None or is_update_model:
    from keras import backend as K
    print("Membuat Model ...")
    print("Mengecek ketersediaan GPU ...", K.tensorflow_backend._get_available_gpus())
    model = create_model()
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,
                       patience=40, min_delta=0.0001)
    
    mcp = ModelCheckpoint(os.path.join(OUTPUT_PATH,
                          "best_model.h5"), monitor='val_loss', verbose=1,
                          save_best_only=True, save_weights_only=False, mode='min', period=1)

    #csv_logger = CSVLogger(os.path.join(OUTPUT_PATH, 'training_log_' + time.ctime().replace(" ","_") + '.log'), append=True)
    
    history = model.fit(x_t, y_t, epochs=params["epochs"], verbose=2, batch_size=BATCH_SIZE,
                        shuffle=False, validation_data=(trim_dataset(x_val, BATCH_SIZE),
                        trim_dataset(y_val, BATCH_SIZE)), callbacks=[es, mcp])
    
    print("Menyimpan model . . .")
    #pickle.dump(model, open("./lstm_model", "wb"))
    model.save("C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes/best_model.h5")
# Out:
# Membuat Model ...
# Mengecek ketersediaan GPU ... []
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 0.04575, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 31s - loss: 0.0335 - accuracy: 4.7619e-04 - val_loss: 0.0458 - val_accuracy: 0.0125
# Epoch 2/200
#
# Epoch 00002: val_loss improved from 0.04575 to 0.01566, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 31s - loss: 0.0328 - accuracy: 4.7619e-04 - val_loss: 0.0157 - val_accuracy: 0.0125
# Epoch 3/200
#
# Epoch 00003: val_loss did not improve from 0.01566
# 105/105 - 35s - loss: 0.0188 - accuracy: 4.7619e-04 - val_loss: 0.0674 - val_accuracy: 0.0125
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 0.01566 to 0.01475, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 38s - loss: 0.0262 - accuracy: 4.7619e-04 - val_loss: 0.0148 - val_accuracy: 0.0125
# Epoch 5/200
#
# Epoch 00005: val_loss did not improve from 0.01475
# 105/105 - 39s - loss: 0.0039 - accuracy: 4.7619e-04 - val_loss: 0.0153 - val_accuracy: 0.0125
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 0.01475
# 105/105 - 36s - loss: 0.0040 - accuracy: 4.7619e-04 - val_loss: 0.0157 - val_accuracy: 0.0125
# Epoch 7/200
#
# Epoch 00007: val_loss did not improve from 0.01475
# 105/105 - 33s - loss: 0.0037 - accuracy: 4.7619e-04 - val_loss: 0.0155 - val_accuracy: 0.0125
# Epoch 8/200
#
# Epoch 00008: val_loss did not improve from 0.01475
# 105/105 - 32s - loss: 0.0034 - accuracy: 4.7619e-04 - val_loss: 0.0151 - val_accuracy: 0.0125
# Epoch 9/200
#
# Epoch 00009: val_loss improved from 0.01475 to 0.01444, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 32s - loss: 0.0032 - accuracy: 4.7619e-04 - val_loss: 0.0144 - val_accuracy: 0.0125
# Epoch 10/200
#
# Epoch 00010: val_loss improved from 0.01444 to 0.01372, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 33s - loss: 0.0030 - accuracy: 4.7619e-04 - val_loss: 0.0137 - val_accuracy: 0.0125
# Epoch 11/200
#
# Epoch 00011: val_loss improved from 0.01372 to 0.01322, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 34s - loss: 0.0030 - accuracy: 4.7619e-04 - val_loss: 0.0132 - val_accuracy: 0.0125
# Epoch 12/200
#
# Epoch 00012: val_loss improved from 0.01322 to 0.01264, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 33s - loss: 0.0029 - accuracy: 4.7619e-04 - val_loss: 0.0126 - val_accuracy: 0.0125
# Epoch 13/200
#
# Epoch 00013: val_loss improved from 0.01264 to 0.01204, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 33s - loss: 0.0029 - accuracy: 4.7619e-04 - val_loss: 0.0120 - val_accuracy: 0.0125
# Epoch 14/200
#
# Epoch 00014: val_loss improved from 0.01204 to 0.01163, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 33s - loss: 0.0028 - accuracy: 4.7619e-04 - val_loss: 0.0116 - val_accuracy: 0.0125
# Epoch 15/200
#
# Epoch 00015: val_loss improved from 0.01163 to 0.01115, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 33s - loss: 0.0027 - accuracy: 4.7619e-04 - val_loss: 0.0112 - val_accuracy: 0.0125
# Epoch 16/200
#
# Epoch 00016: val_loss improved from 0.01115 to 0.01074, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 35s - loss: 0.0028 - accuracy: 4.7619e-04 - val_loss: 0.0107 - val_accuracy: 0.0125
# Epoch 17/200
#
# Epoch 00017: val_loss improved from 0.01074 to 0.01041, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 38s - loss: 0.0027 - accuracy: 4.7619e-04 - val_loss: 0.0104 - val_accuracy: 0.0125
# Epoch 18/200
#
# Epoch 00018: val_loss improved from 0.01041 to 0.01009, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 39s - loss: 0.0027 - accuracy: 4.7619e-04 - val_loss: 0.0101 - val_accuracy: 0.0125
# Epoch 19/200
#
# Epoch 00019: val_loss improved from 0.01009 to 0.00984, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 36s - loss: 0.0026 - accuracy: 4.7619e-04 - val_loss: 0.0098 - val_accuracy: 0.0125
# Epoch 20/200
#
# Epoch 00020: val_loss improved from 0.00984 to 0.00933, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 37s - loss: 0.0025 - accuracy: 4.7619e-04 - val_loss: 0.0093 - val_accuracy: 0.0125
# Epoch 21/200
#
# Epoch 00021: val_loss improved from 0.00933 to 0.00901, saving model to C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes\best_model.h5
# 105/105 - 37s - loss: 0.0025 - accuracy: 4.7619e-04 - val_loss: 0.0090 - val_accuracy: 0.0125
# Epoch 22/200

# %% [markdown]
# # Melakukan Prediksi

# %% [markdown]
# Setelah data berhasil dilatih dengan model yang sudah dibuat, maka selanjutnya adalah proses prediksi

# %% [markdown]
# ## Prediksi dengan data yang masih Normal

# %%
# Melakukan Prediksi dengan model yang sudah dibuat
y_pred = model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)

# Menampilkan nilai Error menggunakan MSE
print("Besarnya nilai Error : ", error, y_pred.shape, y_test_t.shape)
# Out:
# Besarnya nilai Error :  0.0020021624238688684 (256,) (256,)

# %% [markdown]
# ## Proses Denormalisasi data hasil prediksi

# %%
# Melakukan De-normalisasi data output untuk data uji dan data validasi
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]
y_test_t_org = (y_test_t * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3]

# %% [markdown]
# # Visualisasi data output

# %% [markdown]
# ## Visualisasi nilai Loss yang dihasilkan

# %%
# Visualisasi model Loss dari data uji dan data validasi
from matplotlib import pyplot as plt
plt.figure(figsize=[12,6])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.savefig(os.path.join(OUTPUT_PATH, 'train_vis_BS_'+str(BATCH_SIZE)+"_"+'.png'))

# %%
# Menyimpan model
#saved_model = load_model(os.path.join(OUTPUT_PATH, '/content/drive/My Drive/TA_LSTM/outputs/best_model.h5')) 
saved_model = load_model(os.path.join(OUTPUT_PATH, 'best_model.h5')) 
print(saved_model)
# Out:
# <tensorflow.python.keras.engine.sequential.Sequential object at 0x000001C996DFC700>

# %%
y_pred = saved_model.predict(trim_dataset(x_test_t, BATCH_SIZE), batch_size=BATCH_SIZE)
y_pred = y_pred.flatten()
y_test_t = trim_dataset(y_test_t, BATCH_SIZE)
error = mean_squared_error(y_test_t, y_pred)
print("Nilai Error dari MSE sebesar ", error, y_pred.shape, y_test_t.shape)
print("Harga prediksi esok hari sebelum denormalisasi :",y_pred[0])
y_pred_org = (y_pred * min_max_scaler.data_range_[3]) + min_max_scaler.data_min_[3] 
print("Harga prediksi esok hari sesudah denormalisasi :",y_pred_org[0])
# Out:
# Nilai Error dari MSE sebesar  0.0019944847185835433 (256,) (256,)
# Harga prediksi esok hari sebelum denormalisasi : 0.5863721
# Harga prediksi esok hari sesudah denormalisasi : 3032.667

# %% [markdown]
# # Visualisasi hasil prediksi

# %%
kurang = y_pred_org - y_test_t_org
kurang_table = pd.DataFrame(kurang, columns=['hasil pengurangan uji dgn validasi'])
kurang_table.to_csv (r'/content/drive/My Drive/TA_LSTM/outputs/Hasil-pengurangan.csv', index = None, header=True)

# %%
# Visualisasi hasil prediksi dengan model yang sudah dibuat
from matplotlib import pyplot as plt
plt.figure(figsize=[12,6])
plt.plot(y_pred_org)
plt.plot(y_test_t_org)
plt.title('Nilai Prediksi Pergerakan Harga Saham pada PT Adaro Energy Tbk')
plt.ylabel('Price (IDR)')
plt.xlabel('Validation Days')
plt.grid(color='#95a5a6', linestyle='--', linewidth=2, axis='y', alpha=0.7)
plt.legend(['Prediction', 'Real'], loc='lower left')
plt.savefig(os.path.join(OUTPUT_PATH, 'pred_vs_real_BS'+str(BATCH_SIZE)+"_"+'.png'))
print_time("Program selesai pada ", stime)
# Out:
# Program selesai pada  22.0 menit :  39.0 detik

# %% [markdown]
# # Evaluasi Model yang sudah dibuat

# %%
# Evaluasi model
score = model.evaluate(x_t, y_t, batch_size=BATCH_SIZE)
print('Test loss:', score[0])
print('Test accuracy:', "{:.2%}".format(score[1]))
# Out:
# 66/66 [==============================] - 5s 70ms/step - loss: 5.3251e-04 - accuracy: 9.4697e-04
# Test loss: 0.0005325093516148627
# Test accuracy: 0.09%

# %% [markdown]
# # Menyimpan hasil prediksi ke dalam csv

# %%
# Menyimpan hasil data prediksi ke dalam bentuk Dataframe
pred_table = pd.DataFrame(y_pred_org, columns=['Close'])

# Melakukan Ekspor data menjadi bentuk CSV
export_csv = pred_table.to_csv (r'/content/drive/My Drive/TA_LSTM/outputs/Prediksi Close Price.csv', index = None, header=True) 
print ("Dokumen CSV sudah tersimpan di direktori", OUTPUT_PATH)
# Out:
# Dokumen CSV sudah tersimpan di direktori C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes

# %%
# Menggabungkan dataset dengan data lama
df_close = df.drop(columns=['Date','Open', 'High', 'Low', 'Adj Close', 'Volume'])
df_new = pd.concat([df_close, pred_table], ignore_index=True, sort=True)

# Menyimpan dataset baru
export_csv = df_new.to_csv(r'/content/drive/My Drive/TA_LSTM/outputs/Dataset baru.csv', index = None, header=True) 
print ("Dokumen CSV sudah tersimpan di direktori", OUTPUT_PATH)
# Out:
# Dokumen CSV sudah tersimpan di direktori C:/Users/HP/Desktop/Nicky-Skripsi/Program2/outputs/lstmiter_changes
